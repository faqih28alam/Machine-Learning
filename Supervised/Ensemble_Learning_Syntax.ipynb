# %% [markdown]
# ## Gradient Boosting Classifier
#
#
# Tune with cross-validation. Use **GradientBoostingRegressor** for Regression

# %%
#Import the class containing the calssification method
from sklearn.ensemble import GradientBoostingClassifier

# %%
#create an instance of the class
GBC = GradientBoostingClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_features=1,
    subsample=0.5
)

# %%
# Fit the isinstance to the data and predict the expected value 
GBC.fit(X_train, y_train)
y_pred = GBC.predict(X_test)

# %% [markdown]
# ## AdaBoost Classifier
#
# Tune with cross-validation. Use **AdaboostRegressor** for regression

# %%
# Import the class containing the calssification method
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Create an instance of the class
ABC = AdaBoostClassifier(
    base_estimator=DecisionTreeClassifier(),
    learning_rate=0.1,
    n_estimators=200
)

# %%
# Fit the isinstance to the data and predict the expected value 
ABC.fit(X_train, y_train)
y_pred = ABC.predict(X_test)

# %% [markdown]
# ## Voting Classifier
#
# Use **VotingRegressor** for Regression.

# %%
# Impoert the class containing the calssification method
from sklearn.ensemble import VotingClassifier

# %%
# Create an instance of the class
VC = VotingClassifier(
    estimators_list
)

# %%
# Fit the instance to the data and predict the expected value 
VC.fit(X_train, y_train)
y_predict = VC.predict(X_test)
